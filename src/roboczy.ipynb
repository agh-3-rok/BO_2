# %%
import data_matrices as dm
import functions as fn
import numpy as np

chosen_positions = np.random.choice(6, 4, replace=False)

print(chosen_positions)

outer_positions = [
        int(idx) for idx in np.random.choice(
            6, 1, replace=False
        )
    ]
# Out:
# [2 0 1 4]
